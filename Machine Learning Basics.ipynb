# %% [markdown]
# # What is Machine Learning?

# %%
from IPython.display import Image
Image(filename='images/machine_learning_meme.PNG')

# %% [markdown]
# ## Traditional Way of Programming

# %%
from IPython.display import Image
Image(filename='images/traditional_way.PNG')

# %% [markdown]
# ## Machine Learning Way

# %%
from IPython.display import Image
Image(filename='images/machine_learning_way.PNG')

# %%
from IPython.display import Image
Image(filename='images/email_spam_ham.PNG')

# %% [markdown]
# # Real World ML Examples

# %% [markdown]
# ### Web Search Engine
#
# ### Recommendation System ( Amazon, Netflix)
#
# ### Google/Facebook Advertising
#
# ### Speech Recognition
#
# ### Face Detection in FB Photos
#
# ### Live Traffic ( Gmaps ) / Google Car
#
# ### Ola / Uber Surge Pricing/Promotions

# %% [markdown]
# # Why ML is buzzing now ?

# %% [markdown]
# ### Lots of Data
#
# ### High and Cheap Computational Power
#
# ### Increasing Adoption in Real world Applications
#
# ### “ A breakthrough in machine learning would be worth 10 Microsofts” – Bill Gates
#
# ### “Machine Learning is the next Internet” – Tony Tether
#
# ### “ Machines will replace 80% of the doctors “ – Vinod Khosla

# %% [markdown]
# # Types of Machine Leaning

# %%
from IPython.display import Image
Image(filename='images/types_of_ml.PNG')
